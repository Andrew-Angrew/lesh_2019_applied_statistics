# %% [markdown]
# ## Задачи на аналитику
#
# Многие формулировки довольно размытые, уточняйте устно!
# Задачи A1-A11 находится в [pdf-ке](/materials/Nauka_i_zhizn.pdf).
#
# * A12. В начале Первой мировой войны в униформу британских солдат входила коричневая матерчатая фуражка. Металлических касок у них не было. Через некоторое время командование армии было обеспокоено большим количеством ранений в голову. Было решено заменить фуражку металлической каской. Но вскоре командование было удивлено, узнав, что количество ранений в голову увеличилось. Необходимо заметить, что интенсивность сражений была примерно одинаковой до и после введения касок. Так почему же число ранений в голову увеличилось, когда солдаты стали надевать каски, а не фуражки?
#
# * A13. Периодически вузы рассылают своим выпускникам анкеты с вопросами об успешности их карьеры. Почему рэйтинги успешности выпускников, основанные на этих анкетах получаются слишком "оптимистичными"?
#
# * A14. Как вы оцените среднее количество пассажиров в самолетах, прилетающих в аэропорт, если вы можете только опрашивать прилетающих пассажиров о том, сколько пассажиров было в самолете, которым они прилетели?
#
# * A15 как рассчитать размер эксперимента, чтобы доказать эффект определенной силы?
#
# * A16 (старшим) Все-таки хочется уметь досрочно отключать особо плохие эксперименты. Предложите честное решение этой проблемы (сколь угодно костыльное и странное)
#
# * A17 Есть несколько независимых экспериментов, как сделать одно pvalue для гипотезы, что где-то эффект есть? (другими словами как настроить оповещение, которое разбудит тебя ночью, если у тебя в проде что-то сломалось)

# %% [markdown]
# ## Задачи на математику
#
#
#     * Матожидание суммы случайных величин.
#     * Дисперсия суммы независимых случайных величин.
#     * Матожидание выборочной дисперсии
#     * Несмещенная оценка дисперсии.
#     * (math*) Обобщите рассказанный тест Вальда на случай независимых выборок разного размера.
#     * Задача: (math*) Докажите, что если график функции плотности положительной случайной величины выглядит как прямая в логарифмическом масштабе по обеим осям, то:
#         наклон >= -2 => у величины бесконечное матожидание.
#         наклон >= -3 => у величины бесконечная дисперсия.
#
# ### Про распределения
# * Нарисуйти ф-ции распределения и плотности (если она есть) для следующих случайных величин:
#     а) Бернуллиевская
#     б) Дискретная случайная величина, принимающая значение a_i с вероятностью p_i
#     в) Раномерное на [a, b]
#     г) (math*) Сумма двух независимых равномерных на [0, 1]
#     д) (math*) Максимум из двух независимых равномерных на [0, 1]
# * Как должно быть распределено pvalue при условии нулевой гипотезы?
# * Как сгенерировать на компе сэмпл из случайной величины с ф-цией распределния F, если известно как посчитать F^{-1}?
# * (math) Есть два распределения, мы кидаем монетку и если выпал орел сэплируем число из первого распредления, если решка -- из второго. Как выражается ф-ция распределения полученной случайной величины, через ф-ции распределения исходных величин?
# * (math) Как изменится ф-ция распределения случайной величины, если к ней добавить
#     а) константу?
#     б) бернуллиевскую случайную величину с вероятностью единицы равной p?
#     в) (можно нечетко) случайную величину раномерно распределенную на $(-\varepsilon, +\varepsilon)$? Постройте гистограмму в ноутбуке.
# * (math*) Как связаны ф-ция плотности и распределения?
#
# ### Про Манна-Уитни
# * Убедитесь, что статистику Манна-Уитни можно посчитать так: объединить две выборки, отсортировать объединенную выборку, а потом для каждого начального отрезка объединенной и отсортированной выборки нарисовать точку с координатами $(x, y)$, где $x$ и $y$ -- количества объектов в начальном отрезке, пришедших из второй и первой выборки соответственно. Затем соединить построенные точки кривой и посчитать площадь под ее графиком. Какова вычислительная сложность этого алгоритма при аккуратной реализации?
# * Приведите пример таких величин X, Y что P(Y > X) > 1/2, но E(Y) < E(X).
# * Приведите пример таких величин X, Y и Z, что P(Y > X) > 1/2, P(Z > Y) > 1/2 и P(X > Z) > 1/2.
# * (math*) Посчитайте дисперсию статистики Манна-Уитни при условии нулевой гипотезы.
#
# ### Разное
# * (math**) Посчитайте правильное pvalue для "теста Гальтона".

# %% [markdown]
# ## Задачи на програмирование
#
# * Посторйте эмпирическое распределение статистики Манна Уитни для разных размеров выборок при условии нулевой гипотезы.
#
# * поэкcпериментировать с таблицами 2x2 при помощи тестов хи-квадрат, Фишера и Барнарда

# %%
from scipy.special import binom, factorial

# %%
binom(5, 2)
# Out:
# 10.0

# %%
int(factorial(10))
# Out:
# 3628800

# %%
2 * (10 ** 10) * 1000 * 365 / binom(90, 15)
# Out:
# 0.159403702752908
